# %%
import pandas as pd

# %%
df = pd.read_csv('melbourne_house_price.csv')
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
cols_to_drop = ['Lattitude','Regionname','Longtitude','YearBuilt','Postcode']
new_df = df.drop(cols_to_drop, axis='columns')

# %%
df.shape
# Out:
# (34857, 21)

# %%
new_df.shape
# Out:
# (34857, 16)

# %%
df = pd.get_dummies(df, drop_first = True)
df.head()
# Out:
#    Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0      2        NaN       2.5    3067.0       2.0       1.0  1.0     126.0
# 1      2  1480000.0       2.5    3067.0       2.0       1.0  1.0     202.0
# 2      2  1035000.0       2.5    3067.0       2.0       1.0  0.0     156.0
# 3      3        NaN       2.5    3067.0       3.0       2.0  1.0       0.0
# 4      3  1465000.0       2.5    3067.0       3.0       2.0  0.0     134.0
#
#    BuildingArea  YearBuilt  ...  CouncilArea_Wyndham City Council  \
# 0           NaN        NaN  ...                                 0
# 1           NaN        NaN  ...                                 0
# 2          79.0     1900.0  ...                                 0
# 3           NaN        NaN  ...                                 0
# 4         150.0     1900.0  ...                                 0
#
#    CouncilArea_Yarra City Council  CouncilArea_Yarra Ranges Shire Council  \
# ...

# %%
df['new_column'] = (df.Rooms + df.Bathroom )/df.Landsize

# %%
df.head()
# Out:
#    Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0      2        NaN       2.5    3067.0       2.0       1.0  1.0     126.0
# 1      2  1480000.0       2.5    3067.0       2.0       1.0  1.0     202.0
# 2      2  1035000.0       2.5    3067.0       2.0       1.0  0.0     156.0
# 3      3        NaN       2.5    3067.0       3.0       2.0  1.0       0.0
# 4      3  1465000.0       2.5    3067.0       3.0       2.0  0.0     134.0
#
#    BuildingArea  YearBuilt  ...  CouncilArea_Yarra City Council  \
# 0           NaN        NaN  ...                               1
# 1           NaN        NaN  ...                               1
# 2          79.0     1900.0  ...                               1
# 3           NaN        NaN  ...                               1
# 4         150.0     1900.0  ...                               1
#
#    CouncilArea_Yarra Ranges Shire Council  Regionname_Eastern Victoria  \
# ...
